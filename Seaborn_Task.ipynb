# %% [markdown]
# # Visualization Exercise
#
# <img src="logo.jpg"/>

# %% [markdown]
# ### **1.Explore Data**

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#To take a look at the first five rows as default
df = pd.read_csv("Crime_data.csv")
df.head()
# Out:
#    Year           State       District  Rape Cases  Abduction Cases  \
# 0  2018             Goa  Vasco da Gama          21              125
# 1  2019      Tamil Nadu     Coimbatore         136              114
# 2  2019  Madhya Pradesh        Gwalior         133              178
# 3  2021         Haryana        Panipat         102              216
# 4  2020         Tripura       Agartala         100              259
#
#    Murder Cases  Total Crimes Population  Crime Rate  Arrests  \
# 0            38           355     601856       58.98      294
# 1            76           730     454251      160.70      627
# 2            71           748    1881680       39.75      549
# 3            25           558     725939       76.87      435
# 4            75           487    1630786       29.86      363
#
#    Crime Clearance Rate
# 0                 82.82
# 1                 85.89
# 2                273.40
# 3                 77.96
# 4                 74.54

# %%
#To take a look at the last five rows as default
df.tail()
# Out:
#       Year              State       District  Rape Cases  Abduction Cases  \
# 2995  2019            Mizoram       Champhai         139              150
# 2996  2019          Telangana       Warangal          19              300
# 2997  2021  Arunachal Pradesh       Itanagar          22              136
# 2998  2021            Manipur  Churachandpur          58              218
# 2999  2018      Daman and Diu     Vijayawada          75              277
#
#       Murder Cases  Total Crimes Population  Crime Rate  Arrests  \
# 2995             7           778     980131       79.38      620
# 2996            72           833     685975      121.43      661
# 2997            20           439     677041       64.84      316
# 2998            56           777    1970611       39.43      462
# 2999            56           905     390783      231.59      847
#
#       Crime Clearance Rate
# 2995                 79.69
# 2996                 79.35
# 2997                 71.98
# ...

# %%
#print the summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  3000 non-null   int64
#  1   State                 3000 non-null   object
#  2   District              3000 non-null   object
#  3   Rape Cases            3000 non-null   int64
#  4   Abduction Cases       3000 non-null   int64
#  5   Murder Cases          3000 non-null   int64
#  6   Total Crimes          3000 non-null   int64
#  7   Population            3000 non-null   object
#  8   Crime Rate            3000 non-null   float64
#  9   Arrests               3000 non-null   int64
#  10  Crime Clearance Rate  3000 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 257.9+ KB

# %%
#Print the total number of rows and columns in the data set
print("Total rows and columns:", df.shape)
# Out:
# Total rows and columns: (3000, 11)

# %%
# Shows basic statistics for each numerical column in the DataFrame
df.describe()
# Out:
#               Year   Rape Cases  Abduction Cases  Murder Cases  Total Crimes  \
# count  3000.000000  3000.000000      3000.000000   3000.000000   3000.000000
# mean   2019.987667   107.891000       158.363333     53.326333    592.809333
# std       1.404578    82.801182        82.425979     27.673256    168.284082
# min    2018.000000    10.000000        20.000000      5.000000    139.000000
# 25%    2019.000000    56.750000        86.000000     29.000000    472.000000
# 50%    2020.000000   107.000000       158.000000     53.000000    590.000000
# 75%    2021.000000   153.000000       229.000000     77.000000    716.250000
# max    2022.000000  2183.000000       300.000000    100.000000   1043.000000
#
#         Crime Rate      Arrests  Crime Clearance Rate
# count  3000.000000  3000.000000           3000.000000
# mean    112.593547   448.536667             75.753130
# std     154.614185   161.435340             38.926365
# min       9.920000    19.000000              0.450000
# ...

# %%
# Check for nan values if found then drop them
df.isnull().sum()
# removing Nan Value or missing values
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Year                    0
# State                   0
# District                0
# Rape Cases              0
# Abduction Cases         0
# Murder Cases            0
# Total Crimes            0
# Population              0
# Crime Rate              0
# Arrests                 0
# Crime Clearance Rate    0
# dtype: int64

# %%
# Same for duplicates check for them first then drop if found any
df.duplicated().sum()
df = df.drop_duplicates()

# %%
#Count unique values
df.nunique()
# Out:
# Year                       5
# State                     40
# District                 104
# Rape Cases               196
# Abduction Cases          281
# Murder Cases              96
# Total Crimes             723
# Population              2997
# Crime Rate              2693
# Arrests                  687
# Crime Clearance Rate    2236
# dtype: int64

# %% [markdown]
# ### **2.Find the 5 states with the lowest and highest `crime rates`**

# %%
# find the 5 states with the lowest crime rates
print(df.columns)
lowest_crime_states = df.nsmallest(5, 'Crime Rate')
print(lowest_crime_states)
# Out:
# Index(['Year', 'State', 'District', 'Rape Cases', 'Abduction Cases',
#        'Murder Cases', 'Total Crimes', 'Population', 'Crime Rate', 'Arrests',
#        'Crime Clearance Rate'],
#       dtype='object')
#       Year           State     District  Rape Cases  Abduction Cases  \
# 1226  2020       Telangana    Nizamabad          77               26
# 1755  2018         Tripura  Kailashahar          27               38
# 2560  2019      Puducherry     Karaikal          15               99
# 1849  2019  Madhya Pradesh       Bhopal          53               29
# 981   2020          Punjab     Amritsar          10               95
#
#       Murder Cases  Total Crimes Population  Crime Rate  Arrests  \
# 1226            25           196    1975935        9.92      179
# 1755            17           206    1905690       10.81      177
# 2560            17           196    1787360       10.97      141
# 1849            64           205    1827005       11.22     1119
# ...

# %%
# Create a bar plot to visualize the 5 states with the lowest crime rate
lowest_crime_states = df.nsmallest(5, 'Crime Rate')


plt.figure(figsize=(10, 5))
plt.bar(lowest_crime_states['State'], lowest_crime_states['Crime Rate'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Crime Rate')
plt.title('Top 5 States with Lowest Crime Rate')

plt.xticks(rotation=45)
plt.show()

# %%
# get the 5 states with the highest crime rates.
top_5_states = df.sort_values(by='Crime Rate', ascending=False).head(5)

# %%
# Create a bar plot to visualize the 5 states with the Highest crime rate
plt.figure(figsize=(10, 6))
plt.bar(top_5_states['State'], top_5_states['Crime Rate'], color='lightgreen')

# Set title and labels for the plot

plt.title('Top 5 States with Highest Crime Rate', fontsize=14)
plt.xlabel('State', fontsize=12)
plt.ylabel('Crime Rate', fontsize=12)
plt.show()

# %% [markdown]
# ### **3.Find the sum of `Rape Cases` for each year**

# %%
# Group the dataset by 'Year' and calculate the sum of 'Rape Cases' for each year
yearly_cases = df.groupby('Year')['Rape Cases'].sum()

# Plot the line chart showing the trend of total rape cases per year
plt.figure(figsize=(10, 6))
plt.plot(yearly_cases.index, yearly_cases.values, marker='o', linestyle='-', color='red')

plt.title('Trend of Rape Cases per Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Rape Cases', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ### **4.Find the correlation between `total crimes` and `population`**

# %%
# Create a scatter plot with Population on the x-axis and Total Crimes on the y-axis
plt.figure(figsize=(10, 6))
plt.scatter(df['Population'], df['Total Crimes'], color='blue', alpha=0.6)

plt.title('Correlation between Population and Total Crimes', fontsize=14)
plt.xlabel('Population', fontsize=12)
plt.ylabel('Total Crimes', fontsize=12)

plt.show()

# %% [markdown]
# ### **5.Find out how the average of `crime clearance` rate vary across different `states`**

# %%
# Group the data by 'State' and calculate the mean 'Crime Clearance Rate' for each state, then sort them in descending order
state_clearance_rates = df.groupby('State')['Crime Clearance Rate'].mean().sort_values(ascending=False)

# Create a bar plot using the calculated average crime clearance rates
plt.figure(figsize=(12, 6))
plt.bar(state_clearance_rates.index, state_clearance_rates.values, color='brown')

plt.title('Average Crime Clearance Rate per State', fontsize=14)
plt.xlabel('State', fontsize=12)
plt.ylabel('Average Crime Clearance Rate', fontsize=12)
plt.xticks(rotation=90, ha="right")
plt.show()

# %% [markdown]
# ### **6.Find the Outliers of `abduction cases` in `western states`**
#
# Note: wester states are 'Goa', 'Gujarat', 'Maharashtra', 'Rajasthan'

# %%
# Defining the western states
western_states = ['Goa', 'Gujarat', 'Maharashtra', 'Rajasthan']

# Filtering the dataset for western states
western_data = df[df['State'].isin(western_states)]
abduction_cases = western_data['Abduction Cases']
Q1 = abduction_cases.quantile(0.25)
Q3 = abduction_cases.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = western_data[(western_data['Abduction Cases'] < lower_bound) | (western_data['Abduction Cases'] > upper_bound)]
print(outliers[['State', 'District', 'Abduction Cases']])
# After filtering the data for western states (Goa, Gujarat, Maharashtra, Rajasthan),
# we identified outliers in the number of abduction cases using the IQR (Interquartile Range) method.
# Any district with abduction cases significantly higher or lower than the typical range was marked as an outlier.
# These outliers may indicate unusual criminal activity or data irregularities in those specific districts.
#:)

# Plot the boxplot for Abduction Cases in Western States
plt.figure(figsize=(8, 6))
plt.boxplot(western_data['Abduction Cases'], vert=False, patch_artist=True, boxprops=dict(facecolor="lightblue"))
plt.title('Outliers in Abduction Cases in Western States', fontsize=14)
plt.xlabel('Number of Abduction Cases', fontsize=12)
plt.grid(True)
plt.show()
# Out:
# Empty DataFrame
# Columns: [State, District, Abduction Cases]
# Index: []

# %% [markdown]
# ### **7.Find the trend in the number of `murder cases` over the `years`**

# %%
# get the sum of the murder cases over the years
murder_trend = df.groupby('Year')['Murder Cases'].sum()


# Create a line plot with murder cases trend
plt.figure(figsize=(10, 5))
plt.plot(murder_trend.index, murder_trend.values, marker='o', linestyle='-', color='red')
plt.title('Trend of Murder Cases Over the Years', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Murder Cases', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ### **8.Find out which `state` has highest number of `arrest`**

# %%
#pick the top 10 states
arrest_by_state = df.groupby('State')['Arrests'].sum()

#barplot for the top 10 states
top_10_states = arrest_by_state.sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
plt.bar(top_10_states.index, top_10_states.values, color='skyblue')

plt.title('Top 10 States with Highest Number of Arrests', fontsize=14)
plt.xlabel('State', fontsize=12)
plt.ylabel('Total Arrests', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### **9.Find the average `crime rate` across southern states over the `years`**
#
# Note: southern states are 'Andhra Pradesh', 'Telangana', 'Tamil Nadu', 'Karnataka', 'Kerala', 'Puducherry'

# %%
#Southern States

southern_states = ['Andhra Pradesh', 'Telangana', 'Tamil Nadu', 'Karnataka', 'Kerala', 'Puducherry']
# Filter the dataset for Southern States
southern_data = df[df['State'].isin(southern_states)]


# Calculate the average crime rate by state and year
avg_crime_rate = southern_data.groupby('Year')['Crime Rate'].mean()

# Plot the line plot for Southern States

plt.figure(figsize=(10, 5))
plt.plot(avg_crime_rate.index, avg_crime_rate.values, marker='o', linestyle='-', color='b')
plt.title('Average Crime Rate in Southern States Over the Years', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Crime Rate', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ### **10.Find the Total number of `cases` for each crime type**
#
# Note: cases are Rape cases, Abduction cases, Murder cases

# %%
# Sum the cases for each crime type
crime_type_counts = df[['Rape Cases', 'Abduction Cases', 'Murder Cases']].sum()

# Plot the donut chart
plt.figure(figsize=(7, 7))
plt.pie(crime_type_counts, labels=crime_type_counts.index, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'white', 'linewidth': 2})
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
plt.gca().add_artist(centre_circle)
plt.title('Total Number of Cases for Each Crime Type')
plt.show()

# %% [markdown]
# ### **12.Find the Correlation Matrix of Crime Data**

# %%
# Filter data to ensure only numeric data is left

numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(10, 8))
sns.set(style="whitegrid")

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)


plt.title("Correlation Matrix of Crime Data")
plt.show()

# %% [markdown]
# #### **Overall conclusion:**  Write you amazing conclusions about this dataset after you made your analysis

# %%
# Overall Conclusion:
# After analyzing the data, I noticed that crime rates vary a lot from one state to another.
# Some states have consistently low crime rates, while others report much higher numbers.
# I also found a clear link between population and total crimes — areas with more people usually have more crime incidents.
# When I looked into crime clearance rates, I saw that some states are much better at solving crimes than others.
# The trend of rape cases over the years wasn’t stable, which shows the importance of regular monitoring.
# I also found some unusual values in abduction cases in certain western states — these could be signs of special situations or reporting issues.
# Overall, this dataset gave me a good understanding of how crime is spread across regions and how data analysis can help improve public safety.
